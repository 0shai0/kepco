# %%
# !pip install pymysql
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/e5/30/20467e39523d0cfc2b6227902d3687a16364307260c75e6a1cb4422b0c62/PyMySQL-1.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB ? eta 0:00:00
# ...

# %%
import pymysql

# %%
from sqlalchemy import create_engine, text

# %%
## DB 접속
web = "http://"
web_s = "https://"
protocol = "mysql+pymysql://"
user = "root"
password = "1234"
host = "localhost"
port = "3306"
db = "hr"
con_str = f"{protocol}{user}:{password}@{host}:{port}/{db}"
conn = create_engine(con_str)

# %%
con_str
# Out:
# 'mysql+pymysql://root:1234@localhost:3306/hr'

# %%
cur = conn.execute("show tables")

# %%
import pandas as pd
sql_stmt = """
SELECT *
  FROM EMPLOYEES
 WHERE EMPLOYEE_ID > 150
"""
pd.read_sql(sql_stmt,conn)
# Out:
#     employee_id   first_name   last_name     email        phone_number  \
# 0           151        David   Bernstein  DBERNSTE  011.44.1344.345268
# 1           152        Peter        Hall     PHALL  011.44.1344.478968
# 2           153  Christopher       Olsen    COLSEN  011.44.1344.498718
# 3           154      Nanette   Cambrault  NCAMBRAU  011.44.1344.987668
# 4           155       Oliver     Tuvault  OTUVAULT  011.44.1344.486508
# 5           156      Janette        King     JKING  011.44.1345.429268
# 6           157      Patrick       Sully    PSULLY  011.44.1345.929268
# 7           158        Allan      McEwen   AMCEWEN  011.44.1345.829268
# 8           159      Lindsey       Smith    LSMITH  011.44.1345.729268
# 9           160       Louise       Doran    LDORAN  011.44.1345.629268
# 10          161       Sarath      Sewall   SSEWALL  011.44.1345.529268
# 11          162        Clara     Vishney  CVISHNEY  011.44.1346.129268
# ...

# %%
stmt = "delete from school"
conn.execute(stmt)
pd.read_sql(sql_stmt,conn)

# %%
stmt = """
insert into school (id, reg_date, shop_id, user_id)
values(1,1,9,'2012-01-03')
"""
conn.exeute(stmt)

# %%
for i in cur:
    print(i[0])
# Out:
# accident
# board
# board_code
# board_file
# countries
# course01
# course02
# departments
# dept
# emp
# emp_details_view
# employees
# favorite_tb
# it_member
# job_grades
# job_history
# jobs
# locations
# regions
# school
# shop_tag_tb
# shop_tb
# tag_tb
# user_tb
# visitor_tb
