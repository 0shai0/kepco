# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import pandas as pd
from IPython.display import display

data = {'분야': [], 'Time': [], 'Title': [], 'content': []}
links = []

# 첫 번째 URL 데이터 수집 (과학 분야)
for i in range(1, 23):
    try:
        target = 'https://www.etnews.com/news/section.html?id1=20&id2=020&page=' + str(i)
        html = urlopen(target)
        bs = soup(html.read(), 'html.parser')
        tags = bs.select('p > a')
        for tag in tags:
            link = tag.get('href')
            if link not in 'http':
                links.append(link)
    except:
        pass

# 데이터 프레임에 추가 (과학 분야)
for link in links:
    if 'https' in str(link):
        pass
    else:
        result = 'https://www.etnews.com' + link
        try:
            html = urlopen(result)
            bs = soup(html.read(), 'html.parser')
            Time = bs.time.text[6:]
            Title = bs.title.text  # 제목

            # <p> 태그 내의 텍스트를 추출하여 본문에 추가
            content = []
            for paragraph in bs.find_all('article', {'class': 'article_body_wrap'})[0].find_all('p'):
                content.append(paragraph.text.replace('\n', ''))
            content_text = ''.join(content)

            # 데이터 프레임에 추가 (과학 분야)
            data['분야'].append('과학')
            data['Time'].append(Time)
            data['Title'].append(Title)
            data['content'].append(content_text)
        except:
            pass

# 데이터 프레임 생성 (과학 분야)
a_df = pd.DataFrame(data)

# 두 번째 URL 데이터 수집 (에너지 분야)
data2 = {'분야': [], 'Time': [], 'Title': [], 'content': []}
links2 = []

for i in range(1, 82):
    try:
        target = 'https://www.etnews.com/news/section.html?id1=20&id2=065&page=' + str(i)
        html = urlopen(target)
        bs = soup(html.read(), 'html.parser')
        tags = bs.select('p > a')
        for tag in tags:
            link = tag.get('href')
            if link not in 'http':
                links2.append(link)
    except:
        pass

# 데이터 프레임에 추가 (에너지 분야)
for link in links2:
    if 'https' in str(link):
        pass
    else:
        result = 'https://www.etnews.com' + link
        try:
            html = urlopen(result)
            bs = soup(html.read(), 'html.parser')
            Time = bs.time.text[6:]
            Title = bs.title.text  # 제목

            # <p> 태그 내의 텍스트를 추출하여 본문에 추가
            content = []
            for paragraph in bs.find_all('article', {'class': 'article_body_wrap'})[0].find_all('p'):
                content.append(paragraph.text.replace('\n', ''))
            content_text = ''.join(content)

            # 데이터 프레임에 추가 (에너지 분야)
            data2['분야'].append('에너지')
            data2['Time'].append(Time)
            data2['Title'].append(Title)
            data2['content'].append(content_text)
        except:
            pass

# 데이터 프레임 생성 (에너지 분야)
b_df = pd.DataFrame(data2)

# 두 데이터 프레임을 합칠 때 'ignore_index=True' 옵션을 사용하여 인덱스를 재설정
result = pd.concat([a_df, b_df], ignore_index=True)

# 결과 출력
display(result)


# csv로 저장
result.to_csv('수집.csv', index=False)
# Out:
#        분야              Time                                           Title  \
# 0      과학  2023-09-13 16:00       [과학기술이 미래다] 〈102〉국내 첫 퍼스널 컴퓨터 경진대회 - 전자신문
# 1      과학  2023-09-13 07:27                              나노·소재 성과공유회 - 전자신문
# 2      과학  2023-09-12 10:46                        [알림] 테크비즈코리아 2023 - 전자신문
# 3      과학  2023-09-12 07:25                         드럼치는 로봇 '모펫' 입니다 - 전자신문
# 4      과학  2023-09-11 16:11                         드럼치는 로봇 '모펫' 입니다 - 전자신문
# ...   ...               ...                                             ...
# 1530  에너지  2023-03-16 13:15                         현대건설기계, 신규 BI 공개 - 전자신문
# 1531  에너지  2023-03-16 13:10                정부의 전기차 충전기 인프라 정책 개선 방향은 - 전자신문
# 1532  에너지  2023-03-16 13:09  SK㈜, 투로 지분 매각 '2배 수익'...동남아 모빌리티 사업 재투자 - 전자신문
# 1533  에너지  2023-03-16 12:00             환경공단-스타벅스, 커피찌꺼기 재자원화 촉진에 맞손 - 전자신문
# 1534  에너지  2023-03-16 12:00    환경부 '플레어스택' 규제 혁신…“탄소배출량 148만톤 감축 기대” - 전자신문
#
#                                                 content
# 0     1984년 4월 22일. 제1회 퍼스널 컴퓨터 경진대회가 이날 오전 9시 서울 송파...
# 1     나노·소재분야 R&D 정책 및 우수 연구성과를 발표하고 성과물을 공유하는 나노·소재...
# 2     전자신문사가 올해에도 우리 연구 현장의 사업화 유망기술을 민간기업과 투자자에 소개하...
# 3     국내 연구진이 음악 빅데이터 기반 인공지능(AI)을 통해 인간과 상호작용하며 합주 ...
# 4     국내 연구진이 음악 빅데이터 기반 인공지능(AI)을 통해 인간과 상호작용하며 합주 ...
# ...                                                 ...
# 1530  HD현대 건설기계부문 계열사인 현대건설기계는 미국 라스베이거스에서 열리고 있는 세계...
# 1531  한국전기차사용자협회가 주최하는 EVuff@EV트렌드코리아 세미나가 '충전인프라 공급...
# 1532  SK㈜가 미국에서 회수한 투자금을 기반으로 동남아에서 모빌리티 사업을 확장한다.SK...
# 1533  한국환경공단과 스타벅스가 커피찌꺼기 재자원화를 촉진하기 위해 맞손을 잡는다. 커피부...
# 1534  환경부가 '가스연소 굴뚝(플레어스택)' 시설 관리 규정 등을 합리화하는 등 산업현장...
#
# [1535 rows x 4 columns]
